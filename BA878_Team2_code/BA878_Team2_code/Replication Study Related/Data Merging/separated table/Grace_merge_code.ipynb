# %%
import pandas as pd
import numpy as np

# %%
glucose_df = pd.read_csv('/home/jupyter/Grace/glucose.csv')
height_and_weight_df = pd.read_csv('/home/jupyter/Grace/height_and_weight.csv')
hormones_df = pd.read_csv('/home/jupyter/Grace/hormones_and_selfreport.csv')
stress_score_df = pd.read_csv('/home/jupyter/Grace/stress_score.csv')
subject_info = pd.read_csv('/home/jupyter/Grace/subject-info.csv')

# %%
glucose_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 837130 entries, 0 to 837129
# Data columns (total 6 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   id              837130 non-null  int64
#  1   study_interval  837130 non-null  int64
#  2   is_weekend      837130 non-null  bool
#  3   day_in_study    837130 non-null  int64
#  4   timestamp       837130 non-null  object
#  5   glucose_value   835897 non-null  float64
# dtypes: bool(1), float64(1), int64(3), object(1)
# memory usage: 32.7+ MB

# %%
glucose_df.head(20)
# Out:
#     id  study_interval  is_weekend  day_in_study timestamp  glucose_value
# 0    1            2022        True             1  00:04:06            4.9
# 1    1            2022        True             1  00:09:06            5.0
# 2    1            2022        True             1  00:14:07            5.1
# 3    1            2022        True             1  00:19:06            5.1
# 4    1            2022        True             1  00:24:06            5.1
# 5    1            2022        True             1  00:29:06            5.2
# 6    1            2022        True             1  00:34:07            5.3
# 7    1            2022        True             1  00:39:07            5.3
# 8    1            2022        True             1  00:44:07            5.3
# 9    1            2022        True             1  00:49:06            4.9
# 10   1            2022        True             1  00:54:06            5.0
# 11   1            2022        True             1  00:59:07            5.2
# ...
